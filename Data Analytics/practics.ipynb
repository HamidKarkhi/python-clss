# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Hp\Desktop\python clss\Data Analytics\kc_house_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\Hp\Desktop\python clss\Data Analytics\kc_house_data.csv")
#
# File c:\Users\Hp\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.head(-5)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# ...           ...              ...        ...       ...        ...
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1010000.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.tail(-5)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1230000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='str')

# %%
df.iloc[45]
# Out:
# id                    8035350320
# date             20140718T000000
# price                   488000.0
# bedrooms                       3
# bathrooms                    2.5
# sqft_living                 3160
# sqft_lot                   13603
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          8
# sqft_above                  3160
# sqft_basement                  0
# yr_built                    2003
# yr_renovated                   0
# zipcode                    98019
# lat                      47.7443
# long                    -121.977
# sqft_living15               3050
# sqft_lot15                  9232
# Name: 45, dtype: object

# %%
df.iloc[7876]
# Out:
# id                    8682281220
# date             20141014T000000
# price                   439888.0
# bedrooms                       2
# bathrooms                    2.0
# sqft_living                 1300
# sqft_lot                    6515
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          8
# sqft_above                  1300
# sqft_basement                  0
# yr_built                    2005
# yr_renovated                   0
# zipcode                    98053
# lat                      47.7078
# long                    -122.013
# sqft_living15               1640
# sqft_lot15                  6009
# Name: 7876, dtype: object

# %%
df.iloc[8976:998779]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 8976   1126049095  20140926T000000   450000.0         3       2.50
# 8977    126049100  20141104T000000   398000.0         3       1.75
# 8978   1724069060  20150507T000000  1080000.0         2       3.25
# 8979   9530101385  20141014T000000   540000.0         2       2.00
# 8980   7243500015  20141003T000000   275000.0         4       2.00
# ...           ...              ...        ...       ...        ...
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8976          2820     10208     1.0           0     1  ...      8
# ...

# %%
df.loc[5:98]
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 5   7237550310  20140512T000000  1230000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# ..         ...              ...        ...       ...        ...          ...
# 94  6021501535  20141223T000000   700000.0         3       1.50         1580
# 95  1483300570  20140908T000000   905000.0         4       2.50         3300
# 96  3422049190  20150330T000000   247500.0         3       1.75         1960
# 97  1099611230  20140912T000000   199000.0         4       1.50         1160
# 98   722079104  20140711T000000   314000.0         3       1.75         1810
#
# ...

# %%
df.iloc[876]
# Out:
# id                    8802400416
# date             20150213T000000
# price                   147500.0
# bedrooms                       3
# bathrooms                    1.0
# sqft_living                 1530
# sqft_lot                    8498
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1530
# sqft_basement                  0
# yr_built                    1959
# yr_renovated                   0
# zipcode                    98031
# lat                       47.404
# long                    -122.203
# sqft_living15               1380
# sqft_lot15                  8498
# Name: 876, dtype: object

# %%
df.sample(7)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9184   6402700110  20140910T000000  585000.0         4       2.00
# 6510   6043400006  20140729T000000  815000.0         4       1.50
# 17979  9545200180  20141126T000000  575000.0         3       1.75
# 5470   3876810190  20141113T000000  410000.0         4       1.00
# 2317   3253500030  20140725T000000  583000.0         4       2.75
# 13839  4202400395  20150316T000000  285000.0         3       1.75
# 6876   9214400396  20150227T000000  435000.0         2       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9184          2400     12753     1.0           0     0  ...      7
# 6510          2060     16110     1.0           0     0  ...      8
# 17979         2270     10136     2.0           0     0  ...      8
# 5470          1140      7208     1.0           0     0  ...      7
# 2317          2200      9453     1.0           0     0  ...      8
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Hp\Desktop\python clss\Data Analytics\customers-100.csv")

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df.tail()
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
df.sample()
# Out:
#     Index      Customer Id First Name Last Name         Company  \
# 71     72  Ef859092FbEcC07    Richard      Roth  Conway-Mcbride
#
#                 City  Country       Phone 1     Phone 2  \
# 71  New Jasmineshire  Morocco  581-440-6539  9857827463
#
#                           Email Subscription Date                  Website
# 71  aharper@maddox-townsend.org        2020-02-23  https://www.brooks.com/

# %%
df.info
# Out:
# <bound method DataFrame.info of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='str')

# %%
df.columns.tolist()
# Out:
# ['Index',
#  'Customer Id',
#  'First Name',
#  'Last Name',
#  'Company',
#  'City',
#  'Country',
#  'Phone 1',
#  'Phone 2',
#  'Email',
#  'Subscription Date',
#  'Website']

# %%
df.iloc[80:100:2]
# Out:
#     Index      Customer Id First Name Last Name                      Company  \
# 80     81  D6CEAfb3BDbaa1A     Leslie  Jennings            Blankenship-Arias
# 82     83  E8E7e8Cfe516ef0     Hunter    Moreno         Fitzpatrick-Lawrence
# 84     85  03A1E62ADdeb31c      Corey      Holt   Mcdonald, Bird and Ramirez
# 86     87  ebe77E5Bf9476CE      Duane     Woods               Montoya-Miller
# 88     89  efeb73245CDf1fF     Vernon      Kane            Carter-Strickland
# 90     91  5ef6d3eefdD43bE       Nina    Chavez                Byrd-Campbell
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers                Lamb-Peterson
# 94     95  BE91A0bdcA49Bbc    Darrell   Douglas  Newton, Petersen and Mathis
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson        Ware, Burns and Oneal
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer           Fitzgerald-Harrell
#
#                City      Country                Phone 1  \
# 80        Coreybury   Micronesia           629.198.6346
# ...

# %%
df.iloc[87:98]
# Out:
#     Index      Customer Id First Name Last Name                      Company  \
# 87     88  E4Bbcd8AD81fC5f     Alison    Vargas      Vaughn, Watts and Leach
# 88     89  efeb73245CDf1fF     Vernon      Kane            Carter-Strickland
# 89     90  37Ec4B395641c1E       Lori   Flowers              Decker-Mcknight
# 90     91  5ef6d3eefdD43bE       Nina    Chavez                Byrd-Campbell
# 91     92  98b3aeDcC3B9FF3      Shane     Foley                   Rocha-Hart
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers                Lamb-Peterson
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young      Lee, Lucero and Johnson
# 94     95  BE91A0bdcA49Bbc    Darrell   Douglas  Newton, Petersen and Mathis
# 95     96  cb8E23e48d22Eae       Karl     Greer                    Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson        Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra                Schmitt-Jones
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='str')

# %%
df.columns.tolist()
# Out:
# ['Index',
#  'Customer Id',
#  'First Name',
#  'Last Name',
#  'Company',
#  'City',
#  'Country',
#  'Phone 1',
#  'Phone 2',
#  'Email',
#  'Subscription Date',
#  'Website']

# %%
df.sample(9)
# Out:
#     Index      Customer Id First Name  Last Name  \
# 76     77  BF6a1f9bd1bf8DE   Brittany     Zuniga
# 10     11  216E205d6eBb815       Carl  Schroeder
# 16     17  a5DC21AE3a21eaA   Caroline      Foley
# 82     83  E8E7e8Cfe516ef0     Hunter     Moreno
# 22     23  2FB0FAA1d429421    Colleen     Howard
# 3       4  5Cef8BFA16c5e3c      Linda      Olsen
# 66     67  2A13F74EAa7DA6c    Makayla     Cannon
# 68     69  421a109cABDf5fa   Virginia     Dudley
# 50     51  Aa20BDe68eAb0e9     Gerald    Hawkins
#
#                             Company               City  \
# 76                     Mason-Hester      West Reginald
# 10       Oconnell, Meza and Everett       Shannonville
# 16                  Winters-Mendoza  West Adriennestad
# 82             Fitzpatrick-Lawrence       East Clinton
# 22                   Greer and Sons       Brittanyview
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 66                    Henderson Inc         Georgeport
# ...

# %%
df.isnull().sum()
# Out:
# Index                0
# Customer Id          0
# First Name           0
# Last Name            0
# Company              0
# City                 0
# Country              0
# Phone 1              0
# Phone 2              0
# Email                0
# Subscription Date    0
# Website              0
# dtype: int64

# %%
df['Subscription Date'].value_counts()
# Out:
# Subscription Date
# 2021-04-23    2
# 2021-12-02    2
# 2022-01-13    2
# 2022-05-15    2
# 2020-08-24    1
#              ..
# 2022-01-30    1
# 2021-07-10    1
# 2021-09-18    1
# 2021-08-11    1
# 2020-03-11    1
# Name: count, Length: 96, dtype: int64

# %%
df.loc[df['Index'] > 12]
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 12     13  e35426EbDEceaFF     Tracey      Mata         Graham-Francis
# 13     14  A08A8aF8BE9FaD4   Kristine       Cox         Carpenter-Cook
# 14     15  6fEaA1b7cab7B6C      Faith      Lutz         Carter-Hancock
# 15     16  8cad0b4CBceaeec    Miranda   Beasley     Singleton and Sons
# 16     17  a5DC21AE3a21eaA   Caroline     Foley        Winters-Mendoza
# ..    ...              ...        ...       ...                    ...
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                  City          Country               Phone 1  \
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='str')

# %%
df.City
# Out:
# 0          East Leonard
# 1     East Jimmychester
# 2         Isabelborough
# 3            Bensonview
# 4        West Priscilla
#             ...
# 95         East Richard
# 96         New Bradview
# 97           Ortegaland
# 98      Lake Elijahview
# 99            Judymouth
# Name: City, Length: 100, dtype: str

# %%
df.isnull().sum()
# Out:
# Index                0
# Customer Id          0
# First Name           0
# Last Name            0
# Company              0
# City                 0
# Country              0
# Phone 1              0
# Phone 2              0
# Email                0
# Subscription Date    0
# Website              0
# dtype: int64

# %%
df['Country']
# Out:
# 0                          Chile
# 1                       Djibouti
# 2            Antigua and Barbuda
# 3             Dominican Republic
# 4     Slovakia (Slovak Republic)
#                  ...
# 95                        Guyana
# 96                     Sri Lanka
# 97               Solomon Islands
# 98                         Aruba
# 99                      Honduras
# Name: Country, Length: 100, dtype: str

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='str')

# %%
df[['Country', 'Customer Id', 'Company', 'City',
    'Country', 'Phone 1', 'Phone 2']]
# Out:
#                        Country      Customer Id  \
# 0                        Chile  DD37Cf93aecA6Dc
# 1                     Djibouti  1Ef7b82A4CAAD10
# 2          Antigua and Barbuda  6F94879bDAfE5a6
# 3           Dominican Republic  5Cef8BFA16c5e3c
# 4   Slovakia (Slovak Republic)  053d585Ab6b3159
# ..                         ...              ...
# 95                      Guyana  cb8E23e48d22Eae
# 96                   Sri Lanka  CeD220bdAaCfaDf
# 97             Solomon Islands  28CDbC0dFe4b1Db
# 98                       Aruba  c23d1D9EE8DEB0A
# 99                    Honduras  2354a0E336A91A1
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    str
#  2   First Name         100 non-null    str
#  3   Last Name          100 non-null    str
#  4   Company            100 non-null    str
#  5   City               100 non-null    str
#  6   Country            100 non-null    str
#  7   Phone 1            100 non-null    str
#  8   Phone 2            100 non-null    str
#  9   Email              100 non-null    str
#  10  Subscription Date  100 non-null    str
#  11  Website            100 non-null    str
# dtypes: int64(1), str(11)
# memory usage: 9.5 KB

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.histplot(iris, x='sepal_length', y='sepal_width', hue='sepal_width', palette='muted')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.histplot(iris, x='sepal_length', hue='sepal_width',)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(iris, x='sepal_length',  hue='sepal_width', palette='muted')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(iris, y='sepal_width', hue='sepal_width', palette='muted')
# Out:
# <Axes: xlabel='Count', ylabel='sepal_width'>

# %%
sns.histplot(iris, x='sepal_length', y='sepal_width', hue='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.histplot(iris, x='sepal_length', y='sepal_width', palette='muted')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13944\3590290715.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(iris, x='sepal_length', y='sepal_width', palette='muted')
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(titanic, x='embarked', hue='sex')
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
sns.scatterplot(titanic, x='embarked', y='fare', hue='sex')
# Out:
# <Axes: xlabel='embarked', ylabel='fare'>

# %%
sns.histplot(titanic, x='age', bins=[0, 10, 20, 35, 50, 80])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(titanic, x='age')
# Out:
# <Axes: xlabel='age'>
