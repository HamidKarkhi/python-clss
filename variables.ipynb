# %% [markdown]
#  ### `variables`
#  - Variable name can have charactor , digits and underscore
#  - variable cannot start with a digit
#  - variable

# %%
a=2
age=21
print(a)
print(age)
# Out:
# 2
# 21
