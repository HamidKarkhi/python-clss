# %%
stu. = {"name": "Hamid":, "class": 10, "roll_no": 25}:
    print(stu.)
# Out:
#   Cell In[6], line 1
#     stu. = {"name": "Hamid":, "class": 10, "roll_no": 25}:
#          ^
# SyntaxError: invalid syntax

# %%
student = {
    "name": "Hamid",
    "class": 12,
    roll_no
}
