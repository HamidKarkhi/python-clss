# %% [markdown]
# ### Condition
# - if
# - if else
# - multiyple if
# - nested if

# %% [markdown]
# - '= is assignment operator'
# - '== is Equal to operator'

# %%
##1

a=5
b=10
print(a>b) #Greater than operator
# Out:
# False

# %%
##1

a=7
b=9
print(a<b)  #less than operator
# Out:
# True

# %%
##2

c=79
d=79
print(c<d)
# Out:
# False

# %%
##2

c=79
d=79
print(c<=d)  #less than or equal to operator
# Out:
# True

# %% [markdown]
# - ### If Condition

# %%
a=26
if a>18:
    print('Adult')
# Out:
# Adult

# %%
a=10
if a>=18:   
    print('adult')
else :  
    print('kids')
# Out:
# kids

# %%
a=87
if a>=19:
     print('adult')
else:
    print('kids')
# Out:
# adult

# %%
a=8
if a>=18:
    print('adult')
else:
    print('kids')
# Out:
# kids

# %%
a=28
b=76
print(a+b)
# Out:
# 104
