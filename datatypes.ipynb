# %%
a=23
print("integer datatype:",a)
print(str(type(a)))
# Out:
# integer datatype: 23
# <class 'int'>

# %% [markdown]
# - Integer
#     - any numerical value positive or negative
#     - 0 , 5 , -5 , 23242, -23988832,99090909 and so on are integer values

# %% [markdown]
# - Flote
#     - any decimal value positive or negative
#     - 0.01,0.11, -4.3, 100.999 and so on are float

# %% [markdown]
# - String datatype
#   - a character , word or sentence is called a string
#   - staring must me is single quote " or double quotes ""

# %% [markdown]
# - Boolean
#     - True
#     - False
