# %%
c=45
d=37
print(c*d)
# Out:
# 1665

# %%
print(3**4)
# Out:
# 81

# %%
c=45
d=37
print(c**d)
# Out:
# 14752411218392995193903431272552826630999334156513214111328125

# %%
print(7**6)
# Out:
# 117649

# %%
a=9
b=6

# %%
a=2
b=3
print(2/3)
# Out:
# 0.6666666666666666

# %%
a=7
b=9
print(a>b)
# Out:
# False

# %%
c=79
d=79
print(c<d)  #less than operator
# Out:
# False

# %%
a=78
b=45
print(a+b)
# Out:
# 123

# %%
a=67
b=76
print(a/b)
# Out:
# 0.881578947368421

# %%
a=67
b=76
print(a*b)
# Out:
# 5092

# %%
a=67
b=76
print(a*b)
# Out:
# 5092

# %%
a=89
b=87
print(a//b)
# Out:
# 1

# %%
name="hamid"
surname="Chaudhry"
print(name)
print(surname)
# Out:
# hamid
# Chaudhry

# %%
a=672
b=6.87
print(a/b)
# Out:
# 97.81659388646288

# %%
marks = int(input("take input marks"))

if marks<=100 and marks>=90:
    print("Grafe A")
elif marks<=90 and marks>=70:
    print("Grade B")
elif marks<=70 and marks>=50:
    print("Grade C")
else:
    print("fail")

# %%
a = int(input("Take input number: "))
b = int(input("Take input number: "))
if a > b:
    print("a<b")
else:
    print("a>b")
# Out:
# a>b

# %%
a = 98709
b = 7257

if a>b:
    print("a>b")
else:
    print("a<b")
# Out:
# a>b

# %%
num = int(input("76: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
a = int(input("Take a number from user"))

if a%2==0:
    print("odd")
elif a%2!=0:
    print("Even")
else:
    print("zero")
# Out:
# odd

# %%
age = int(input("98: "))
if age >= 18:
    print("eligible for vote")
else:
    print("not eligible for vote")
# Out:
# eligible for vote

# %%
marks = int(input("Take input from person"))

if marks<=100 and marks>=90:
    print("Grade A")
elif marks<=100 and marks>=70:
    print("Grade B")
else:
    print("Fail")
# Out:
# Fail

# %%
a = float(input("Take input from user"))

if a%3==0 and a%6!=0:
    print("divisibal by 3 and not divisibal by 6")
else:
    print("not divisibal by 3 and 6")
# Out:
# not divisibal by 3 and 6

# %%
age = 190

if age>=18:
    print("eligibal for driving license")
elif age>=100:
    print("old person")
else:
    print("not eligibal for driving license")
# Out:
# eligibal for driving license
