# %% [markdown]
# ##### esme ye hota hai jaise 153 koi digit le lo aap yaa (XYZ...) kuch bhi le skte ho aur jitna digit liye hai uska sabhi per squair kro sabhi per fir sabhi ko plush kro ager jo digit liye hai aur jo squire kiye hai dono same aa gya to armstrong number hai jaise
#
# - 153 = 1**3 + 5**3 + 3**3   ye dono apas me brabar hon acahiye tab armstrong number hoga
#
# - 1657 = 1**4 + 6**4 + 5**4 + 7**4 es tarh se hoga

# %%
a = 3
b = 3**3
print(b)
# Out:
# 27

# %%
num = int(input("Enter the number"))
original = num
digits = len(str(num))

sum_of_power = 0

while num>0:
    digit = num%10
    sum_of_power += digit ** digits
    num = num//10

if original == sum_of_power:
    print("Armstrong Number")
else:
    print("Not Armstrong Number")
# Out:
# Not Armstrong Number

# %%
num = inr(INPUT("take input from user"))
org = num
digit = len(str(num))

sum_of_power = 0

while num>0:
