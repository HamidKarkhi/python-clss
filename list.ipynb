# %% [markdown]
# # 8 june

# %%
mylist = [454, 'hello, 373.38, True']

# %%
type(mylist)
# Out:
# list

# %%
mylist
# Out:
# [454, 'hello, 373.38, True']

# %% [markdown]
# # indexing

# %%
fruits = [ 'apple', 'orange', 'pineapple', 'lichi', 'mango' ]

# %%
# indexing

print(fruits[2])
print(fruits[-3])
# Out:
# pineapple
# pineapple

# %%
fruits.index('lichi')
# Out:
# 3

# %%
fruits.index('guvava')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 fruits.index('guvava')
#
# ValueError: 'guvava' is not in list

# %%
# slicin

fruits[1:4]
# Out:
# ['orange', 'pineapple', 'lichi']

# %%
fruits[-4: -1]
# Out:
# ['orange', 'pineapple', 'lichi']

# %%
fruits[1: -1]
# Out:
# ['orange', 'pineapple', 'lichi']

# %%
fruits[1:]
# Out:
# ['orange', 'pineapple', 'lichi', 'mango']

# %%
# esme sabhi element skip kr kr dega hm 2 ko badha ghta skte hai apme hisaab se kr skte hai usi hisaab se answer aayega
fruits[::2]
# Out:
# ['apple', 'pineapple', 'mango']

# %%
# esme sabhi element skip kr kr dega hm 1 ko badha ghta skte hai apme hisaab se kr skte hai usi hisaab se answer aayega
s[::-1]
# Out:
# ['mango', 'lichi', 'pineapple', 'orange', 'apple']

# %%
# ham revesrse me commond de skte hai kaha se kaha tak jana hai -2 start krna hai and 0 tak chlna hai -1 eska mtlab hai etna eta s
# kip krna hai
fruits[-2:0:-1]
# Out:
# ['lichi', 'pineapple', 'orange']

# %%
movies = ['resident evil', 'ddlj', 'dhurander', 'bhoot bangla', 'PK']

# %% [markdown]
# #  what is the indext of dhurender
# # find last 3 element from list
# # wap for [ 'ddlj, 'resident evil']
# # wap for [ 'ddlj', 'bhoot bangla']
# # ['PK', 'bhoot bngla']

# %%
movies(-3:-1)
# Out:
#   Cell In[16], line 1
#     movies(-3:-1)
#              ^
# SyntaxError: invalid syntax

# %%
movies[-5:-3]
# Out:
# ['resident evil', 'ddlj']

# %%
movies[-1::-1]
# Out:
# ['PK', 'bhoot bangla', 'dhurander', 'ddlj', 'resident evil']

# %%
movies[1::2]
# Out:
# ['ddlj', 'bhoot bangla']

# %%
movies[-2:-3:-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 movies[-2:-3:-1]
#
# NameError: name 'movies' is not defined

# %%
# adding and removing elements
fruits.append('guava')
print(fruits)
# Out:
# ['guava']

# %%
fruits.pop()
# Out:
# 'guava'

# %%
print(fruits)
# Out:
# []

# %%
fruits.remove('orange')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 fruits.remove('orange')
#
# ValueError: list.remove(x): x not in list
